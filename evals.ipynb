# %%
from inspect_ai import eval_async, Task
from property_listing_content_generator.solvers import baseline
from property_listing_content_generator.evaluation import all_evaluations 

from inspect_ai.scorer import model_graded_qa
from inspect_ai.solver import generate, system_message

solver = baseline.baseline_solver

for evaluation in all_evaluations():
    content_generator_eval = Task(
        dataset=evaluation.dataset,
        solver=solver,
        scorer=evaluation.scorer
    )
    
    await eval_async(
        content_generator_eval,
        model="anthropic/claude-haiku-4-5-20251001"
    )
# Out:
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
# ---------------------------------------------------------
# Steps:   1/1 100% | Samples:   1/  1 | accuracy: 1.00 | anthropic:  0/20 | HTTP retries: 0
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
#
# total time:                          0:00:05
# anthropic/claude-haiku-4-5-20251001  1,849 tokens [I: 1,387, CW: 0, CR: 0, O: 462]
# model_graded_qa
# accuracy         1.000
# stderr           0.000
# Log: logs/2026-05-21T00-16-36-00-00_task_nQA8CXdXJ3rNuJyS8WnoHS.eval
# ---------------------------------------------------------
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
# ---------------------------------------------------------
# Steps:   1/1 100% | Samples:   1/  1 | accuracy:  n/a | anthropic:  0/20 | HTTP retries: 0
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
#
# total time:                          0:00:05
# anthropic/claude-haiku-4-5-20251001  1,971 tokens [I: 1,427, CW: 0, CR: 0, O: 544]
# model_graded_qa
# accuracy         1.000
# stderr           0.000
# Log: logs/2026-05-21T00-16-41-00-00_task_RU9gZoZfv5UWzbgLivXmJb.eval
# ---------------------------------------------------------
