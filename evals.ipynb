# %%
from inspect_ai import eval_async
from inspect_ai import Task
from property_listing_content_generator.samples import easy_samples
from property_listing_content_generator.solvers import baseline

from inspect_ai.scorer import model_graded_qa
from inspect_ai.solver import generate, system_message

content_generator_eval = Task(
    dataset=easy_samples.easy_samples,
    solver=baseline.baseline_solver,
    scorer=model_graded_qa()
)

await eval_async(
    content_generator_eval,
    model="anthropic/claude-haiku-4-5-20251001"
)
# Out:
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
# ---------------------------------------------------------
# Steps:   1/1 100% | Samples:   1/  1 | accuracy: 1.00 | anthropic:  0/20 | HTTP retries: 0
# ---------------------------------------------------------
# task (1 sample): anthropic/claude-haiku-4-5-20251001
# dataset: (samples)
#
# total time:                          0:00:05
# anthropic/claude-haiku-4-5-20251001  1,922 tokens [I: 1,405, CW: 0, CR: 0, O: 517]
# model_graded_qa
# accuracy         1.000
# stderr           0.000
# Log: logs/2026-05-20T21-59-19-00-00_task_6hGtmJSqhu8DjWHL6a4zV7.eval
# ---------------------------------------------------------
